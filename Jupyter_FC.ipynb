# %% [markdown]
# # Group Name - Jupyter FC
# Team Memebers:Brian Mooney, Alex o'Brien, Sankalp Raj Srivastava

# %% [markdown]
# # Problem Statement
# It’s your turn to be the manager/ scout/ recruiter . . .Now you need to put your analytics skills to the test, applying them to the problem of creating a ‘Dream Team’ . Your goal is to find a team of 11 players which could rival that of any primer league squad.
# Rules:
# I.You need to follow a 4-4-2 formation plus a goal keeper.
# II.You have a total market value of €80 Million Euro

# %%
#Uploading the CSV file on Google Collab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-631c2324-adab-4a6d-913f-cf2bc5bb4838" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-631c2324-adab-4a6d-913f-cf2bc5bb4838">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving PlayerData.csv to PlayerData (2).csv

# %%
#Creating DataFrame for the CSV
dataframe = pd.read_csv('PlayerData (2).csv')

# %%
dataframe.head()
# Out:
#         Player                   Team  ... Penalties taken Penalty conversion, %
# 0   F. Uscanga               Tlaxcala  ...               4                  50.0
# 1     V. Henry                  Rodez  ...               0                   0.0
# 2     A. Turan             Ankaragücü  ...               0                   0.0
# 3   P. Bourdin      Beerschot-Wilrijk  ...               0                   0.0
# 4  C. Villalba  Talleres Córdoba Res.  ...               0                   0.0
#
# [5 rows x 113 columns]

# %%
#Checking null values
dataframe.isnull().sum()
# Out:
# Player                              0
# Team                                3
# Position                            0
# 1st Position                        0
# Age                                 0
#                                  ...
# Direct free kicks per 90          310
# Direct free kicks on target, %    310
# Corners per 90                     20
# Penalties taken                     0
# Penalty conversion, %               0
# Length: 113, dtype: int64

# %%
#DataFrame for GoalKeepers
GK_df = dataframe[(dataframe['1st Position'] ==  "GK")]

# %%
GK_df.head()
# Out:
#           Player                  Team  ... Penalties taken Penalty conversion, %
# 6    G. Espinoza  Cimarrones de Sonora  ...               0                   0.0
# 19     P. Patron               Le Mans  ...               0                   0.0
# 90        M. Lis          Wisła Kraków  ...               0                   0.0
# 124  B. Siegrist         Dundee United  ...               0                   0.0
# 127  E. Volynets       Kolos Kovalivka  ...               0                   0.0
#
# [5 rows x 113 columns]

# %%
#Ranking GoalKeepers based on Conceded goals per 90
GK_df["Rank"] = GK_df["Conceded goals per 90"].rank()
GK_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           Player                  Team  ... Penalty conversion, %   Rank
# 6    G. Espinoza  Cimarrones de Sonora  ...                   0.0  104.0
# 19     P. Patron               Le Mans  ...                   0.0   71.5
# 90        M. Lis          Wisła Kraków  ...                   0.0  159.5
# 124  B. Siegrist         Dundee United  ...                   0.0  119.0
# 127  E. Volynets       Kolos Kovalivka  ...                   0.0   79.0
#
# [5 rows x 114 columns]

# %%
#Sorting values against the features selected for Goalkeeper.
GK_df = GK_df.sort_values(["Shots against per 90", "Clean sheets","Save rate, %","Prevented goals per 90","Conceded goals per 90"], ascending = (True, False,True,False,True))

# %%
GK_df.head(20)
# Out:
#               Player             Team  ... Penalty conversion, %   Rank
# 2046  Luís Maximiano      Sporting CP  ...                   0.0   10.5
# 4729      Z. Steffen  Manchester City  ...                   0.0    2.0
# 675       R. Majecki           Monaco  ...                   0.0    1.0
# 1143        A. Rossi     Boca Juniors  ...                   0.0    4.0
# 512        V. Barkas           Celtic  ...                   0.0   37.0
# 1497       A. Desmas         Clermont  ...                   0.0    5.5
# 5124      B. Lecomte           Monaco  ...                   0.0   60.5
# 4790     Diogo Costa            Porto  ...                   0.0  185.5
# 3926          H. Lak       Persepolis  ...                   0.0    7.0
# 530         G. Rulli       Villarreal  ...                   0.0   14.0
# 1572     P. Niazmand          Sepahan  ...                   0.0   71.5
# 2349      C. Maxwell        Blackpool  ...                   0.0   26.0
# ...

# %%
#Creating DataFrame for Left Back
LB_df = dataframe[(dataframe['1st Position'] ==  "LB")]

# %%
LB_df.head(10)
# Out:
#               Player           Team  ... Penalties taken Penalty conversion, %
# 2           A. Turan     Ankaragücü  ...               0                   0.0
# 33          D. Potts     Luton Town  ...               0                   0.0
# 48    Carlos Pomares       Tenerife  ...               0                   0.0
# 56   K. Hovhannisyan         Kairat  ...               0                   0.0
# 57         K. Haugen          Molde  ...               0                   0.0
# 68        I. Panţîru  FCS Bucureşti  ...               0                   0.0
# 78      K. Krizmanić         Gorica  ...               0                   0.0
# 117          V. Mora       Tlaxcala  ...               0                   0.0
# 134        I. Diallo        Ajaccio  ...               0                   0.0
# 157      D. Mosquera       Santa Fe  ...               0                   0.0
#
# [10 rows x 113 columns]

# %%
#Sorting values for LeftBack based on selected features.
LB_df = LB_df.sort_values(["Defensive duels per 90", "Defensive duels won, %","Aerial duels per 90","Aerial duels won, %","Sliding tackles per 90","Accurate passes to final third, %","Deep completed crosses per 90"], ascending = (False, False,False, False,False, False,False))

# %%
LB_df.head(10)
# Out:
#             Player             Team  ... Penalty conversion, %   Rank
# 419     N. Zolotov  Kolos Kovalivka  ...                   0.0  318.0
# 1178         Fábio           Nantes  ...                   0.0  346.0
# 2437      N. Hefti             Thun  ...                   0.0  294.5
# 1181     C. Traoré           Nantes  ...                   0.0  123.0
# 5385     J. Robson    Dundee United  ...                   0.0   59.5
# 5400     Y. Fukuda      Gamba Osaka  ...                   0.0  147.0
# 2906  T. Pellenard     Valenciennes  ...                   0.0  101.5
# 4580   T. Mitchell   Crystal Palace  ...                   0.0  247.0
# 586      F. Ortega  Vélez Sarsfield  ...                   0.0  287.0
# 2605      B. Conus            Aarau  ...                   0.0  275.0
#
# [10 rows x 114 columns]

# %%
#Ranking Leftback based on "Defensive duels won, %"
LB_df["Rank"] = LB_df["Defensive duels won, %"].rank()
LB_df.head(20)
# Out:
#               Player              Team  ... Penalty conversion, %   Rank
# 419       N. Zolotov   Kolos Kovalivka  ...                 0.000  318.0
# 1178           Fábio            Nantes  ...                 0.000  346.0
# 2437        N. Hefti              Thun  ...                 0.000  294.5
# 1181       C. Traoré            Nantes  ...                 0.000  123.0
# 5385       J. Robson     Dundee United  ...                 0.000   59.5
# 5400       Y. Fukuda       Gamba Osaka  ...                 0.000  147.0
# 2906    T. Pellenard      Valenciennes  ...                 0.000  101.5
# 4580     T. Mitchell    Crystal Palace  ...                 0.000  247.0
# 586        F. Ortega   Vélez Sarsfield  ...                 0.000  287.0
# 2605        B. Conus             Aarau  ...                 0.000  275.0
# 802        J. Angulo             Atlas  ...                 0.000  307.0
# 3675       B. Pittón       San Lorenzo  ...                 0.000  326.0
# ...

# %%
#Creating DataFrame for RightBack position
RB_df = dataframe[(dataframe['1st Position'] ==  "RB")]

# %%
#Sorting DataFrame based on selected features for RighBack
RB_df = RB_df.sort_values(["xA per 90", "Crosses per 90","Accurate crosses, %","Dribbles per 90","Successful dribbles, %","Progressive runs per 90","Accelerations per 90"], ascending = (False, False,False, False,False, False,False))

# %%
#Ranking DataFrame based on "Accurate crosses, %"
RB_df["Rank"] = RB_df["Accurate crosses, %"].rank()
RB_df.head(20)
# Out:
#                Player                Team  ... Penalty conversion, %   Rank
# 5307     J. Tavernier             Rangers  ...                83.333  166.0
# 5280  Diogo Gonçalves             Benfica  ...                 0.000  286.0
# 2444         A. Forde       Oxford United  ...                 0.000  429.0
# 662         J. Murphy    Newcastle United  ...                 0.000  377.0
# 5657  C. Borchgrevink           Vålerenga  ...                 0.000  424.0
# 2194       S. Klaiber                Ajax  ...                 0.000  396.5
# 3809          Arnaldo         Atlético GO  ...                 0.000  347.0
# 2818    Lucas Vázquez         Real Madrid  ...                 0.000  314.0
# 2039        H. Siquet  Standard Liège U21  ...                 0.000  406.0
# 3093      K. Bartolec           København  ...                 0.000  202.5
# 3341    R. Fredericks     West Ham United  ...                 0.000  438.0
# ...

# %%
#Eliminating redundant columns
RB_df1 = RB_df[['Player', 'Team', 'Position', '1st Position', 'Age', 'Market value', "xA per 90", "Crosses per 90","Accurate crosses, %","Dribbles per 90","Successful dribbles, %","Progressive runs per 90","Accelerations per 90",'Matches played', 'Minutes played', 'Goals', 'Rank']].copy()

# %%
RB_df1.head(20)
# Out:
#                Player                Team  ... Goals   Rank
# 5307     J. Tavernier             Rangers  ...    19  166.0
# 5280  Diogo Gonçalves             Benfica  ...     4  286.0
# 2444         A. Forde       Oxford United  ...     1  429.0
# 662         J. Murphy    Newcastle United  ...     7  377.0
# 5657  C. Borchgrevink           Vålerenga  ...     2  424.0
# 2194       S. Klaiber                Ajax  ...     1  396.5
# 3809          Arnaldo         Atlético GO  ...     1  347.0
# 2818    Lucas Vázquez         Real Madrid  ...     2  314.0
# 2039        H. Siquet  Standard Liège U21  ...     0  406.0
# 3093      K. Bartolec           København  ...     2  202.5
# 3341    R. Fredericks     West Ham United  ...     1  438.0
# 5018       R. Aguilar              Monaco  ...     2  321.0
# 916      M. Gaćinović          Hoffenheim  ...     1  168.5
# 1435     O. Danchenko          AEK Athens  ...     0  319.5
# 2618     B. van Rooij                 NEC  ...     4  368.0
# ...

# %%
#Creating DataFrame for Left Center back position
LCB_df = dataframe[(dataframe['1st Position'] ==  "LCB")]

# %%
LCB_df.head()
# Out:
#            Player               Team  ... Penalties taken Penalty conversion, %
# 3      P. Bourdin  Beerschot-Wilrijk  ...               0                   0.0
# 20      P. Ouaneh      Concarneau US  ...               0                   0.0
# 24        Maracás  Paços de Ferreira  ...               0                   0.0
# 43  R. Nicolaisen         Portsmouth  ...               0                   0.0
# 44      K. Medina            Qarabag  ...               0                   0.0
#
# [5 rows x 113 columns]

# %%
#Eliminating redundant columns
LCB_df1 = LCB_df[['Player', 'Team', 'Position', '1st Position', 'Age', 'Market value', "Successful defensive actions per 90", "Passes per 90","Accurate passes, %","Forward passes per 90","Accurate forward passes, %","Short / medium passes per 90","Accurate short / medium passes, %",'Matches played', 'Minutes played', 'Goals']].copy()

# %%
LCB_df1.head()
# Out:
#            Player               Team  ... Minutes played Goals
# 3      P. Bourdin  Beerschot-Wilrijk  ...           2280     3
# 20      P. Ouaneh      Concarneau US  ...           3070     4
# 24        Maracás  Paços de Ferreira  ...           2876     2
# 43  R. Nicolaisen         Portsmouth  ...           2214     1
# 44      K. Medina            Qarabag  ...           3190     0
#
# [5 rows x 16 columns]

# %%
#Sorting DataFrame based on selected features for Left Center Back
LCB_df1 = LCB_df1.sort_values(["Successful defensive actions per 90", "Passes per 90","Accurate passes, %","Forward passes per 90","Accurate forward passes, %","Short / medium passes per 90","Accurate short / medium passes, %"], ascending = (False, False,False, False,False, False,False))

# %%
#Ranking DataFrame based on "Accurate passes, %"
LCB_df1["Rank"] = LCB_df1["Accurate passes, %"].rank()
LCB_df1.head(20)
# Out:
#                 Player                 Team  ... Goals   Rank
# 2794         M. Senesi            Feyenoord  ...     3  187.0
# 1162         K. Pierie               Twente  ...     0  102.5
# 3390     Nurio Fortuna                 Gent  ...     2   47.0
# 334          N. Sibisi        Golden Arrows  ...     0  118.0
# 1079          K. Bryan     Sheffield United  ...     1   23.0
# 5493         E. Haugan        Östersunds FK  ...     1  240.0
# 2500       N. Havenaar                 Thun  ...     5  206.5
# 5609        Léo Coelho                Fénix  ...     1   19.5
# 3055           B. Okoh            Liefering  ...     1   29.0
# 1491  J. Van den Bergh    Beerschot-Wilrijk  ...     4   30.0
# 5667       D. Gugganig  WSG Swarovski Tirol  ...     2   60.0
# 1012          G. Ortíz     Atlético Tucumán  ...     2   43.0
# 5166            Bremer               Torino  ...     7  206.5
# 5690      S. Bryzgalov                Fakel  ...     4   73.5
# ...

# %%
#Creating DataFrame for Mid Fielder position
MF_df = dataframe[(dataframe['1st Position'] ==  "LCMF")]

# %%
#Eliminating redundant columns
MF_df1 = MF_df[['Player', 'Team', 'Position', '1st Position', 'Age', 'Market value','Matches played', 'Minutes played', 'Goals', "Passes per 90","Accurate passes, %","Forward passes per 90","Accurate forward passes, %","Short / medium passes per 90","Accurate short / medium passes, %","Long passes per 90","Accurate long passes, %","Passes to final third per 90","Accurate passes to final third, %","Progressive passes per 90","Accurate progressive passes, %"]].copy()

# %%
#Sorting DataFrame based on selected features for Mid Fielder
MF_df1 = MF_df1.sort_values(["Passes per 90","Accurate passes, %","Forward passes per 90","Accurate forward passes, %","Short / medium passes per 90","Accurate short / medium passes, %","Long passes per 90","Accurate long passes, %","Passes to final third per 90","Accurate passes to final third, %","Progressive passes per 90","Accurate progressive passes, %"], ascending = (False))

# %%
#Ranking DataFrame based on "Accurate passes, %"
MF_df1["Rank"] = MF_df1["Accurate passes, %"].rank()
MF_df1.head(20)
# Out:
#              Player                Team  ... Accurate progressive passes, %   Rank
# 2821    M. Verratti                 PSG  ...                          87.76  434.0
# 2339       H. Akino    V-Varen Nagasaki  ...                          85.08  435.0
# 1772   J. McEachran  Milton Keynes Dons  ...                          82.76  389.0
# 656      G. Cuéllar            Al Hilal  ...                          88.27  442.0
# 5155     B. Gilmour             Chelsea  ...                          77.33  425.0
# 149    E. Andersson          Djurgården  ...                          79.17  346.0
# 4594    C. McGregor              Celtic  ...                          85.06  428.0
# 1580       K. Fukai   Consadole Sapporo  ...                          78.18  438.0
# 1799  Yong-Woo Park     Gimcheon Sangmu  ...                          82.41  352.0
# 5532    R. Harakawa        Cerezo Osaka  ...                          77.48  421.5
# ...

# %%
#Creating DataFrame for DMF position
DMF_df = dataframe[(dataframe['1st Position'] ==  "DMF")]

# %%
#Eliminating redundant columns
DMF_df1 = DMF_df[['Player', 'Team', 'Position', '1st Position', 'Age', 'Market value','Matches played', 'Minutes played', 'Goals', "Defensive duels per 90", "Defensive duels won, %","Sliding tackles per 90","Interceptions per 90","Passes per 90","Accurate passes, %","Lateral passes per 90","Accurate lateral passes, %"]].copy()

# %%
#Sorting DataFrame based on selected features for DMF
DMF_df1 = DMF_df1.sort_values(["Defensive duels per 90", "Defensive duels won, %","Sliding tackles per 90","Interceptions per 90","Passes per 90","Accurate passes, %","Lateral passes per 90","Accurate lateral passes, %"], ascending = (False))
DMF_df1.head()
# Out:
#             Player  ... Accurate lateral passes, %
# 64      E. Camalov  ...                      93.97
# 820       A. Cubas  ...                      93.70
# 1550    A. Arregui  ...                      88.14
# 5497    M. Mellado  ...                      90.78
# 314   J. Biegański  ...                      92.89
#
# [5 rows x 17 columns]

# %%
#Raking DataFrame based on "Interceptions per 90"
DMF_df1["Rank"] = DMF_df1["Interceptions per 90"].rank()
DMF_df1.head(20)
# Out:
#                   Player                Team  ... Accurate lateral passes, %   Rank
# 64            E. Camalov                Zira  ...                      93.97  190.0
# 820             A. Cubas               Nîmes  ...                      93.70   88.0
# 1550          A. Arregui       Independiente  ...                      88.14  162.0
# 5497          M. Mellado                 OFI  ...                      90.78  123.0
# 314         J. Biegański       Lechia Gdańsk  ...                      92.89  148.0
# 123        T. Pietermaat   Beerschot-Wilrijk  ...                      92.26  164.0
# 4175       R. Fishchenko               Veles  ...                      88.59  137.0
# 632             J. Ferri         Montpellier  ...                      92.75    5.0
# 808          M. Frendrup             Brøndby  ...                      88.00  128.0
# 3685           C. Rivera        Club Tijuana  ...                      94.59   27.5
# ...

# %%
#Creating DataFrame for LWF position
LWF_df = dataframe[(dataframe['1st Position'] ==  "LWF")]

# %%
#Eliminating redundant columns
LWF_df1 = LWF_df[['Player', 'Team', 'Position', '1st Position', 'Age', 'Market value','Matches played', 'Minutes played', 'Goals', "xG per 90", "xA per 90","Successful attacking actions per 90","Crosses per 90","Accurate crosses, %","Dribbles per 90","Successful dribbles, %","Offensive duels per 90","Offensive duels won, %","Corners per 90"]].copy()

# %%
#Sorting DataFrame based on selected features for LWF
#Raking DataFrame based on "xA per 90"

LWF_df1 = LWF_df1.sort_values(["xG per 90", "xA per 90","Successful attacking actions per 90","Crosses per 90","Accurate crosses, %","Dribbles per 90","Successful dribbles, %","Offensive duels per 90","Offensive duels won, %","Corners per 90"], ascending = (False))
LWF_df1["Rank"] = LWF_df1["xA per 90"].rank()
LWF_df1.head(20)
# Out:
#                 Player                Team  ... Corners per 90  Rank
# 4886    K. Toko Ekambi  Olympique Lyonnais  ...           0.05  13.0
# 2259          A. Katai       Crvena Zvezda  ...           3.21  42.0
# 1950        S. Vecchia           Rosenborg  ...           0.89  31.5
# 3993         A. Schalk            Servette  ...           0.07  16.0
# 5187          J. Hauge               Milan  ...           0.41  35.0
# 4919     Ricardo Horta      Sporting Braga  ...           1.29  26.5
# 5257        V. Mihăilă               Parma  ...           0.17  16.0
# 4026      V. Edvardsen           Degerfors  ...           0.49  39.5
# 1021         J. Koroma   Huddersfield Town  ...           0.00  13.0
# 119          I. Kallon             Cambuur  ...           0.25  20.0
# 4548    S. El Shaarawy                Roma  ...           0.00  20.0
# 3612       P. Almqvist              Rostov  ...           0.10   7.5
# 4352         E. D'Ursi                Bari  ...           0.76   7.5
# ...

# %%
#Creating DataFrame for RWF position
RWF_df = dataframe[(dataframe['1st Position'] ==  "RWF")]

# %%
#Eliminating redundant columns
RWF_df1 = RWF_df[['Player', 'Team', 'Position', '1st Position', 'Age', 'Market value','Matches played', 'Minutes played', 'Goals', "xG per 90", "xA per 90","Successful attacking actions per 90","Crosses per 90","Accurate crosses, %","Dribbles per 90","Successful dribbles, %","Offensive duels per 90","Offensive duels won, %","Corners per 90"]].copy()

# %%
#Sorting DataFrame based on selected features for RWF
#Raking DataFrame based on "xA per 90"
RWF_df1 = RWF_df1.sort_values(["xG per 90", "xA per 90","Successful attacking actions per 90","Crosses per 90","Accurate crosses, %","Dribbles per 90","Successful dribbles, %","Offensive duels per 90","Offensive duels won, %","Corners per 90"], ascending = (False))
RWF_df1["Rank"] = RWF_df1["xA per 90"].rank()
RWF_df1.head(20)
# Out:
#                Player                 Team  ... Corners per 90  Rank
# 4207      B. Gurtsiev  Alaniya Vladikavkaz  ...           1.45  27.0
# 4955      T. Kadewere   Olympique Lyonnais  ...           0.04   7.5
# 3226         G. Iancu        Akhmat Grozny  ...           1.79  16.0
# 1217  P. Zinckernagel              Watford  ...           4.96  45.0
# 5048      S. Berghuis            Feyenoord  ...           3.36  43.0
# 2594        K. Tagawa                Tokyo  ...           0.00   4.5
# 5174           D. Man                Parma  ...           0.32  22.5
# 150       E. Chilufya           Djurgården  ...           0.00  33.5
# 94       N. Shipnoski          Saarbrücken  ...           0.00  16.0
# 2694    E. Volpicelli             Matelica  ...           2.14  33.5
# 1232        A. Gruber            LASK Linz  ...           0.29  22.5
# 3408          A. Amoo             Hammarby  ...           0.08   7.5
# 4020       C. Chiricò               Padova  ...           1.90  33.5
# ...

# %%
#Creating DataFrame for CF position
CF_df = dataframe[(dataframe['1st Position'] ==  "CF")]

# %%
#Eliminating redundant columns
CF_df1 = CF_df[['Player', 'Team', 'Position', '1st Position', 'Age', 'Market value','Matches played', 'Minutes played', 'Goals',"Successful attacking actions per 90","xG per 90","Shots per 90","Shots on target, %","Goal conversion, %","Touches in box per 90","Penalties taken","Penalty conversion, %"]].copy()

# %%
#Sorting DataFrame based on selected features for CF
#Raking DataFrame based on "xG per 90"
CF_df1 = CF_df1.sort_values(["Successful attacking actions per 90","xG per 90","Shots per 90","Shots on target, %","Goal conversion, %","Touches in box per 90","Penalties taken","Penalty conversion, %"], ascending = (False))
CF_df1["Rank"] = CF_df1["xG per 90"].rank()
# Out:
#                Player                 Team  ... Penalty conversion, %   Rank
# 2773           Neymar                  PSG  ...                91.667  934.5
# 1033      F. Castillo         Club Tijuana  ...                 0.000   62.5
# 5312         A. Ounas              Crotone  ...                 0.000   45.5
# 3759        O. Bukari                 Gent  ...                 0.000  372.0
# 3615        R. Mirzov               Khimki  ...               100.000  208.0
# 5198      K. Sulemana         Nordsjælland  ...                50.000  521.5
# 1396       N. Barrios  Central Córdoba SdE  ...                 0.000    3.5
# 2933        V. Burgoa           Godoy Cruz  ...                 0.000   25.5
# 5577        J. Zwarts            Excelsior  ...                 0.000  406.0
# 3250       M. Phaeton             Guingamp  ...                 0.000  435.0
# 2843      N. Ninković              Brescia  ...                 0.000  112.0
# ...

# %%
CF_df1.head(40)
# Out:
#                Player                 Team  ... Penalty conversion, %   Rank
# 2773           Neymar                  PSG  ...                91.667  934.5
# 1033      F. Castillo         Club Tijuana  ...                 0.000   62.5
# 5312         A. Ounas              Crotone  ...                 0.000   45.5
# 3759        O. Bukari                 Gent  ...                 0.000  372.0
# 3615        R. Mirzov               Khimki  ...               100.000  208.0
# 5198      K. Sulemana         Nordsjælland  ...                50.000  521.5
# 1396       N. Barrios  Central Córdoba SdE  ...                 0.000    3.5
# 2933        V. Burgoa           Godoy Cruz  ...                 0.000   25.5
# 5577        J. Zwarts            Excelsior  ...                 0.000  406.0
# 3250       M. Phaeton             Guingamp  ...                 0.000  435.0
# 2843      N. Ninković              Brescia  ...                 0.000  112.0
# ...

# %% [markdown]
# We decided that we wanted to build a team of 442 with attacking wingbacks and ball playing defenders.
# Our goal keeper is R.Majecki from Monaco worth 10 million
# Our left back is M.Mittelstadt from Hertha worth 7 million
# Our right back is H.Siquet from standard liege worth 5 million
# Our centre backs are J.Panzo from Dijon worth 4 million
# And B.Diakite from Toulouse worth 7 million
#
# One of our centre mids is a deep lying play maker, we chose G.Cuellar from Al Hilal worth 4 million for this
# The other centre mid is a ball winning mid. We chose E Alvarez Balanta from club brugge worth 4.5 million
# Our left winger is there for assist and goals as well as crossing. We chose J.Hauge from Milan worth 9.5 million
#
# Our right winger is there for a similar reason to the left winger but with more of a focus at passing. We chose D.Man from Parma worth 10 million
#
# Our two strikers are K.Sulemana from Nordsjaelland worth 9 million and S.Koita from Salzburg worth 12.5. These players have great goals per game and xG and Koita being young has good upside and potential.
#
#
# Total cost of this team is 76.5 million
